# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

train = pd.read_csv(r'data/dataset.csv')
df = train.copy()

# %%
df = df.drop('High cholesterol level', axis=1)
df = df.drop('Chest pain', axis=1)
df = df.drop('No of days physically active per week', axis=1)
df = df.drop('Heart Rate', axis=1)
df = df.drop('At least 12 alcoholic drinks during lifetime', axis=1)

# %%
df.columns
# Out:
# Index(['Id', 'Diabetes family history', 'Age',
#        'Ate fast food during last 12 months', 'Sleep time', 'Gender', 'Weight',
#        'HDL Cholesterol', 'LDL Cholesterol', 'Total Cholesterol',
#        'Total calcium', 'Height', 'Red blood cell count',
#        'White blood cell count', 'Platelet count', 'Hemoglobin', 'Hematocrit',
#        'Glucose', 'Sodium', 'Potassium', 'Bicarbonate', 'Chloride',
#        'Blood urea nitrogen', 'Creatinine', 'Albumin', 'Total protein',
#        'Alkaline phosphatase', 'Alanine aminotransferase',
#        'Aspartate aminotransferase', 'Total bilirubin', 'Pulse', 'Arthritis',
#        'High blood pressure', 'Heart attack', 'Stroke', 'BMI',
#        'At least 12 alcoholic drinks during any year', 'Liver Condition'],
#       dtype='object')

# %%
from scipy import stats

# %%
df_filtered = df[df['Diabetes family history'] != 9]
sns.countplot(x="Diabetes family history",data=df_filtered)
# Out:
# <Axes: xlabel='Diabetes family history', ylabel='count'>

# %%
df_filtered = df[df['Sleep time'] != 99]
sns.countplot(x="Sleep time",data=df_filtered)
# Out:
# <Axes: xlabel='Sleep time', ylabel='count'>

# %%
df_filtered = df[df['Arthritis'] != 9]
sns.countplot(x="Arthritis",data=df_filtered)
# Out:
# <Axes: xlabel='Arthritis', ylabel='count'>

# %%
df_filtered = df[df['High blood pressure'] != 9]
sns.countplot(x="High blood pressure",data=df_filtered)
# Out:
# <Axes: xlabel='High blood pressure', ylabel='count'>

# %%
df_filtered = df[df['Heart attack'] != 9]
sns.countplot(x="Heart attack",data=df_filtered)
# Out:
# <Axes: xlabel='Heart attack', ylabel='count'>

# %%
df_filtered = df[df['Stroke'] != 9]
sns.countplot(x="Stroke",data=df_filtered)
# Out:
# <Axes: xlabel='Stroke', ylabel='count'>

# %%
df_filtered = df[df['At least 12 alcoholic drinks during any year'] != 9]
sns.countplot(x="At least 12 alcoholic drinks during any year",data=df_filtered)
# Out:
# <Axes: xlabel='At least 12 alcoholic drinks during any year', ylabel='count'>

# %%
df_filtered = df[df['Liver Condition'] != 9]
sns.countplot(x="Liver Condition",data=df_filtered)
# Out:
# <Axes: xlabel='Liver Condition', ylabel='count'>
