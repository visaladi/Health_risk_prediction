# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

train = pd.read_csv(r'data/dataset.csv')
df = train.copy()
df.head()
# Out:
#    Id  Diabetes family history  Age  No of days physically active per week  \
# 0   1                      NaN   69                                    NaN
# 1   2                      NaN   54                                    NaN
# 2   3                      NaN   72                                    NaN
# 3   4                      NaN   33                                    5.0
# 4   5                      2.0   78                                    NaN
#
#    High cholesterol level  Ate fast food during last 12 months  Sleep time  \
# 0                     1.0                                  1.0         7.0
# 1                     1.0                                  1.0         9.0
# 2                     1.0                                  2.0         8.0
# 3                     NaN                                  NaN         NaN
# 4                     2.0                                  1.0         9.0
#
# ...

# %%
df.tail()
# Out:
#         Id  Diabetes family history  Age  \
# 9808  9809                      2.0   41
# 9809  9810                      NaN   50
# 9810  9811                      2.0   30
# 9811  9812                      2.0   65
# 9812  9813                      2.0   63
#
#       No of days physically active per week  High cholesterol level  \
# 9808                                    NaN                     2.0
# 9809                                    NaN                     NaN
# 9810                                    NaN                     2.0
# 9811                                    NaN                     2.0
# 9812                                    NaN                     2.0
#
#       Ate fast food during last 12 months  Sleep time  Gender  Weight  \
# 9808                                  2.0         7.0       2    71.8
# 9809                                  NaN         NaN       1    11.3
# 9810                                  1.0         5.0       1    89.6
# ...

# %%
df.describe()
# Out:
#                Id  Diabetes family history          Age  \
# count  9813.00000              6232.000000  9813.000000
# mean   4907.00000                 1.887356    45.974524
# std    2832.91343                 0.520318    15.619148
# min       1.00000                 1.000000    18.000000
# 25%    2454.00000                 2.000000    34.000000
# 50%    4907.00000                 2.000000    43.000000
# 75%    7360.00000                 2.000000    56.000000
# max    9813.00000                 9.000000    80.000000
#
#        No of days physically active per week  High cholesterol level  \
# count                            2887.000000             6229.000000
# mean                                5.805681                1.723712
# std                                 5.354061                0.711127
# min                                 0.000000                1.000000
# 25%                                 4.000000                1.000000
# ...

# %%
df.shape
# Out:
# (9813, 43)

# %%
df.columns
# Out:
# Index(['Id', 'Diabetes family history', 'Age',
#        'No of days physically active per week', 'High cholesterol level',
#        'Ate fast food during last 12 months', 'Sleep time', 'Gender', 'Weight',
#        'HDL Cholesterol', 'LDL Cholesterol', 'Total Cholesterol',
#        'Total calcium', 'Height', 'Red blood cell count',
#        'White blood cell count', 'Platelet count', 'Hemoglobin', 'Hematocrit',
#        'Glucose', 'Sodium', 'Potassium', 'Bicarbonate', 'Chloride',
#        'Blood urea nitrogen', 'Creatinine', 'Albumin', 'Total protein',
#        'Alkaline phosphatase', 'Alanine aminotransferase',
#        'Aspartate aminotransferase', 'Total bilirubin', 'Heart Rate', 'Pulse',
#        'Chest pain', 'Arthritis', 'High blood pressure', 'Heart attack',
#        'Stroke', 'BMI', 'At least 12 alcoholic drinks during lifetime',
#        'At least 12 alcoholic drinks during any year', 'Liver Condition'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                                                 0
# Diabetes family history                         3581
# Age                                                0
# No of days physically active per week           6926
# High cholesterol level                          3584
# Ate fast food during last 12 months             3584
# Sleep time                                      3586
# Gender                                             0
# Weight                                            90
# HDL Cholesterol                                 2189
# LDL Cholesterol                                 6708
# Total Cholesterol                               2189
# Total calcium                                   3302
# Height                                           746
# Red blood cell count                            1269
# White blood cell count                          1269
# Platelet count                                  1269
# Hemoglobin                                      1269
# ...
